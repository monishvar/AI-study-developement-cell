# %% [markdown]
# <a href="https://colab.research.google.com/github/monishvar/AI-study-developement-cell/blob/master/Face_recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
import cvlib as cv
image_path = 'FB_IMG_1553397641098.jpg'
im = cv2.imread(image_path)
plt.imshow(im)
plt.show()
faces, confidences = cv.detect_face(im)
for face in faces:
  (startX,startY) = face[0],face[1]
  (endX,endY) = face[2],face[3]
  cv2.rectangle(im, (startX,startY), (endX,endY),(0,255,0), 2)
  plt.imshow(im)
  plt.show()

# %%
# !pip3 install cvlib
# Out:
# ...
#      |████████████████████████████████| 10.0MB 4.8MB/s
# ...
#   Created wheel for cvlib: filename=cvlib-0.2.3-cp36-none-any.whl size=10043491 sha256=3fc69e3876835e4f38a147c0083d2721da84def24c3b48a8a9cc1efa2c80ab15
#   Stored in directory: /root/.cache/pip/wheels/c9/83/ca/701a48deacbc78758f33173252feb97297316c40af783264e2
# ...
#   Created wheel for progressbar: filename=progressbar-2.5-cp36-none-any.whl size=12073 sha256=a36a635c53377f2e373deb6466c436bedac93f1d037d5dbc72243e14b8ab032b
#   Stored in directory: /root/.cache/pip/wheels/c0/e9/6b/ea01090205e285175842339aa3b491adeb4015206cda272ff0
# Successfully built cvlib progressbar
# ...
