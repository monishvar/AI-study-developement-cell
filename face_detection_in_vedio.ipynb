# %% [markdown]
# <a href="https://colab.research.google.com/github/monishvar/AI-study-developement-cell/blob/master/face_detection_in_vedio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries
import cv2
import face_recognition
from google.colab.patches import cv2_imshow

#get a reference to video
video_capture = cv2.VideoCapture("WhatsApp Video 2019-12-31 at 5.11.20 PM.mp4")

#intialize variables
face_locations = []
while True:

  #grab a single frame = video_capture.read()
  ret, frame = video_capture.read()

  #convert the image from BGR color (which OpenCV uses)to RGB color 
  rgb_frame = frame[:, :, ::-1]

  #find all the faces in the current frame of video
  face_locations = face_recognition.face_locations(rgb_frame)

  #display the results
  for top, right, bottom, left in face_locations:

    #draw a box around the face
    cv2.rectangle(frame, (left, top), (right, bottom),(0, 0, 255), 2)

  #display the resulting image
  cv2_imshow(frame)

  #hit 'q' on the keyboard to quit!
  if cv2.waitKey(1) & 0xFF == ord('q'):
    break

  #release handle to the webcam
  video_capture.release()
  cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=480x480 at 0x7FEA8814B4A8>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-d131547d19b2> in <module>()
#      14
#      15   #convert the image from BGR color (which OpenCV uses)to RGB color
# ---> 16   rgb_frame = frame[:, :, ::-1]
#      17
#      18   #find all the faces in the current frame of video
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# !pip3 install face_recognition
# Out:
# ...
#      |████████████████████████████████| 100.2MB 106kB/s
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566176 sha256=5c7ef27acf63eb59b4ad3e73f94410e2c33e326f4d5d58da0e65dd34477f0e66
#   Stored in directory: /root/.cache/pip/wheels/d2/99/18/59c6c8f01e39810415c0e63f5bede7d83dfb0ffc039865465f
# Successfully built face-recognition-models
# ...
